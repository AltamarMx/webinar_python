# %%
from windrose import WindroseAxes
import pandas as pd
import matplotlib.pyplot as plt

# %%
viento = pd.read_csv('../data/ws_wd.csv',index_col=0,parse_dates=True)
viento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 148620 entries, 2022-03-12 15:00:23 to NaT
# Data columns (total 5 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   u       148560 non-null  float64
#  1   v       148560 non-null  float64
#  2   w       148560 non-null  float64
#  3   ws      148560 non-null  float64
#  4   wd      148560 non-null  float64
# dtypes: float64(5)
# memory usage: 6.8 MB

# %%
viento.plot(subplots=True,figsize=(10,4))
# Out:
# array([<AxesSubplot:xlabel='fecha'>, <AxesSubplot:xlabel='fecha'>,
#        <AxesSubplot:xlabel='fecha'>, <AxesSubplot:xlabel='fecha'>,
#        <AxesSubplot:xlabel='fecha'>], dtype=object)

# %%
fig, ax = plt.subplots(2,1,figsize=(10,6),sharex=True)

ax[0].plot(viento.ws,'k.')
ax[1].plot(viento.wd,'r.')

ax[1].set_ylim(0,360)
ax[1].set_xlabel('Tiempo DD HH:MM')
ax[0].set_ylabel('velocidad ($m/s$)')
ax[1].set_ylabel('Direccion ($^o$)')
# Out:
# Text(0, 0.5, 'Direccion ($^o$)')

# %%
ax = WindroseAxes.from_ax()
ax.bar(viento.wd, viento.ws, normed=True, opening=0.8, edgecolor="white")
ax.set_legend()

# %%
wind = viento
ax = WindroseAxes.from_ax()
ax.bar(viento.wd, viento.ws, normed=True, opening=0.8, edgecolor="white")
ax.set_legend()
