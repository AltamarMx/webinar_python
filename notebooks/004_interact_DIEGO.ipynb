# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from ipywidgets import interact
import ipywidgets as widgets

# %%
viento = pd.read_csv("../data/ws_wd.csv", index_col=0, parse_dates=True)
viento = viento[:-1]

# %%
time=10
resam = viento.resample(f"{time}s").mean()
fig, ax = plt.subplots(figsize=(15,5))
ax.plot(resam.ws, marker="o")

# %%
def prom_vels(time):
    resam = viento.resample(f"{time}s").mean()
    fig, ax = plt.subplots(figsize=(15,5))
    ax.plot(resam.ws, marker="o")
#     ax.plot(viento.ws,'k-',alpha=0.2)

# %%
interact(prom_vels, time=[1,5,10,15,30,45,60])
# Out:
# interactive(children=(Dropdown(description='time', options=(1, 5, 10, 15, 30, 45, 60), value=1), Output()), _d…
# <function __main__.prom_vels(time)>
