# %%
import pandas as pd
import glob as glob

# %%
f = '../data/03_11_22 [Anemometer 1]-0.txt'
nombres = ['u','v','w','fecha']
tmp = pd.read_csv(f,skiprows=5,usecols=[1,2,3,7],names=nombres)
tmp.fecha = tmp.fecha.str.replace('p. m.','PM',regex=True)
tmp.fecha = tmp.fecha.str.replace('a. m.','AM',regex=True)
tmp.fecha = pd.to_datetime(tmp.fecha, format='%d/%m/%Y %I:%M:%S %p')
tmp.set_index('fecha',inplace=True)

# %%
def importa(f):
    f = '../data/03_11_22 [Anemometer 1]-0.txt'
    nombres = ['u','v','w','fecha']
    tmp = pd.read_csv(f,skiprows=5,usecols=[1,2,3,7],names=nombres)
    tmp.fecha = tmp.fecha.str.replace('p. m.','PM',regex=True)
    tmp.fecha = tmp.fecha.str.replace('a. m.','AM',regex=True)
    tmp.fecha = pd.to_datetime(tmp.fecha, format='%d/%m/%Y %I:%M:%S %p')
    tmp.set_index('fecha',inplace=True)
    return tmp

# %%
archivos =  glob.glob('../data/*.txt')
archivos
# Out:
# ['../data/03_11_22 [Anemometer 1]-14.txt',
#  '../data/03_11_22 [Anemometer 1]-28.txt',
#  '../data/03_11_22 [Anemometer 1]-29.txt',
#  '../data/03_11_22 [Anemometer 1]-15.txt',
#  '../data/03_11_22 [Anemometer 1]-17.txt',
#  '../data/03_11_22 [Anemometer 1]-16.txt',
#  '../data/03_11_22 [Anemometer 1]-9.txt',
#  '../data/03_11_22 [Anemometer 1]-12.txt',
#  '../data/03_11_22 [Anemometer 1]-13.txt',
#  '../data/03_11_22 [Anemometer 1]-8.txt',
#  '../data/03_11_22 [Anemometer 1]-11.txt',
#  '../data/03_11_22 [Anemometer 1]-10.txt',
#  '../data/03_11_22 [Anemometer 2]-1.txt',
#  '../data/03_11_22 [Anemometer 2]-17.txt',
#  '../data/03_11_22 [Anemometer 2]-16.txt',
#  '../data/03_11_22 [Anemometer 2]-0.txt',
#  '../data/03_11_22 [Anemometer 2]-2.txt',
#  '../data/03_11_22 [Anemometer 2]-14.txt',
#  '../data/03_11_22 [Anemometer 2]-28.txt',
#  '../data/03_11_22 [Anemometer 2]-29.txt',
#  '../data/03_11_22 [Anemometer 2]-15.txt',
#  '../data/03_11_22 [Anemometer 2]-3.txt',
#  '../data/03_11_22 [Anemometer 2]-7.txt',
#  '../data/03_11_22 [Anemometer 2]-11.txt',
#  '../data/03_11_22 [Anemometer 2]-10.txt',
#  '../data/03_11_22 [Anemometer 2]-6.txt',
#  '../data/03_11_22 [Anemometer 2]-4.txt',
#  '../data/03_11_22 [Anemometer 2]-12.txt',
#  '../data/03_11_22 [Anemometer 2]-13.txt',
#  '../data/03_11_22 [Anemometer 2]-5.txt',
#  '../data/03_11_22 [Anemometer 2]-8.txt',
#  '../data/03_11_22 [Anemometer 2]-22.txt',
#  '../data/03_11_22 [Anemometer 2]-23.txt',
#  '../data/03_11_22 [Anemometer 2]-9.txt',
#  '../data/03_11_22 [Anemometer 2]-21.txt',
#  '../data/03_11_22 [Anemometer 2]-20.txt',
#  '../data/03_11_22 [Anemometer 2]-18.txt',
#  '../data/03_11_22 [Anemometer 2]-24.txt',
#  '../data/03_11_22 [Anemometer 2]-25.txt',
#  '../data/03_11_22 [Anemometer 2]-19.txt',
#  '../data/03_11_22 [Anemometer 2]-27.txt',
#  '../data/03_11_22 [Anemometer 2]-26.txt',
#  '../data/03_11_22 [Anemometer 1]-6.txt',
#  '../data/03_11_22 [Anemometer 1]-21.txt',
#  '../data/03_11_22 [Anemometer 1]-20.txt',
#  '../data/03_11_22 [Anemometer 1]-7.txt',
#  '../data/03_11_22 [Anemometer 1]-5.txt',
#  '../data/03_11_22 [Anemometer 1]-22.txt',
#  '../data/03_11_22 [Anemometer 1]-23.txt',
#  '../data/03_11_22 [Anemometer 1]-4.txt',
#  '../data/03_11_22 [Anemometer 1]-0.txt',
#  '../data/03_11_22 [Anemometer 1]-27.txt',
#  '../data/03_11_22 [Anemometer 1]-26.txt',
#  '../data/03_11_22 [Anemometer 1]-1.txt',
#  '../data/03_11_22 [Anemometer 1]-3.txt',
#  '../data/03_11_22 [Anemometer 1]-18.txt',
#  '../data/03_11_22 [Anemometer 1]-24.txt',
#  '../data/03_11_22 [Anemometer 1]-25.txt',
#  '../data/03_11_22 [Anemometer 1]-19.txt',
#  '../data/03_11_22 [Anemometer 1]-2.txt']

# %%
len(archivos)
# Out:
# 60

# %%
df = pd.concat([importa(archivo) for archivo in archivos])

# %%
df.plot(subplots=True,figsize=(10,12))
# Out:
# array([<AxesSubplot:xlabel='fecha'>, <AxesSubplot:xlabel='fecha'>,
#        <AxesSubplot:xlabel='fecha'>], dtype=object)

# %%
df.to_csv('../data/u_v_w.csv')
